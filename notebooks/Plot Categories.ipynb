# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import hist

df_tags = pd.read_csv('df_tags')

category = [0, 1, 2, 3, 4, 5, 6]
count = [31744, 1654907, 721, 2377892, 1889250, 2007, 59207]

df = pd.DataFrame({'category' : category, 'count' : count})

# %%
print(df)
import seaborn as sns
palette = sns.husl_palette(9, s=0.7 )
ax = sns.countplot(x=df_tags['category'])
# Out:
#    category    count
# 0         0    31744
# 1         1  1654907
# 2         2      721
# 3         3  2377892
# 4         4  1889250
# 5         5     2007
# 6         6    59207

# %%
# print(df_tags.tail(100))
df_tags.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115aeba10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115b64c10>]], dtype=object)
